# %%
import os 
os.chdir("C:\\Users\\Jyotsna Nag\\Desktop\\Machine Learning\\Kaggle Projects\\Pokemon visualisation")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
pokemon=pd.read_csv('Pokemon.csv')

# %%
pokemon.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
pokemon = pokemon.drop(['Generation', 'Legendary'],1)

# %%
plt.figure(1,figsize=(15,6))
sns.jointplot('HP','Attack',data=pokemon)
plt.show()

# %%
sns.boxplot(x='HP',data=pokemon)

# %%
pokemon = pokemon.drop(['Total', '#'],1)

# %%
pokemon.head()
# Out:
#                     Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0              Bulbasaur  Grass  Poison  45      49       49       65
# 1                Ivysaur  Grass  Poison  60      62       63       80
# 2               Venusaur  Grass  Poison  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed
# 0       65     45
# 1       80     60
# 2      100     80
# 3      120     80
# 4       50     65

# %%
plt.figure(figsize=(15,7))
sns.boxplot(data=pokemon)
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
pokemon=pd.melt(pokemon,id_vars=['Name','Type 1','Type 2'],var_name='Stat')

# %%
pokemon.head()
# Out:
#                     Name Type 1  Type 2 Stat  value
# 0              Bulbasaur  Grass  Poison   HP     45
# 1                Ivysaur  Grass  Poison   HP     60
# 2               Venusaur  Grass  Poison   HP     80
# 3  VenusaurMega Venusaur  Grass  Poison   HP     80
# 4             Charmander   Fire     NaN   HP     39

# %%
plt.figure(figsize=(15,7))
plt.ylim(0, 275)
sns.swarmplot(data=pokemon,x='Stat',y='value',hue='Type 1')
plt.title('Pokemon Stats')
plt.legend(bbox_to_anchor=(1, 1), loc=2, borderaxespad=0.)

# %%
sns.set_style("whitegrid")
with sns.color_palette([
    "#8ED752", "#F95643", "#53AFFE", "#C3D221", "#BBBDAF",
    "#AD5CA2", "#F8E64E", "#F0CA42", "#F9AEFE", "#A35449",
    "#FB61B4", "#CDBD72", "#7673DA", "#66EBFF", "#8B76FF",
    "#8E6856", "#C3C1D7", "#75A4F9"], n_colors=18, desat=.9):
    plt.figure(figsize=(15,7))
    plt.ylim(0, 275)
    sns.swarmplot(x="Stat", y="value", data=pokemon, hue="Type 1", split=True, size=7)
    plt.legend(bbox_to_anchor=(1, 1), loc=2, borderaxespad=0.);
